# %% [markdown]
# # Test visualize

# %%
from visualize.visualize import Visualize
vis = Visualize()

# %%
import matplotlib.pyplot as plt
# vis.plot_loss_update(0.1, 0.5)
image = plt.imread("E:\data\BrainTumor\images\\4_1.jpg")
vis.update_image(image[:,:,0])
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x2F70AFB54C0>

# %%
image = plt.imread("E:\data\BrainTumor\images\\8_1.jpg")
vis.update_image(image[:,:,0])

# %% [markdown]
# # Test SegmentationData

# %%
from data.SegmentationData import SegmentationData
from config import config
data = SegmentationData(config)

# %%
# data.show_batch()

# %% [markdown]
# # Test trainer

# %%
from data.SegmentationData import SegmentationData
from config import config
from train.train import Trainer
data = SegmentationData(config)
trainer = Trainer(config, data)

# %%
trainer.train()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='536' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.19% [1/536 05:47<51:37:46]
#     </div>
# <PIL.Image.Image image mode=RGB size=576x384 at 0x12A80393400>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='77' class='' max='77' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [77/77 05:29<00:00]
#     </div>
# Epoch   0 step  0: loss train: 0.405543, loss valid: 0.678083, dice valid: 0.000000, learning rate: 0.001000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# E:\vinbrain-internship\segmentation\train\train.py in train(self, loss_file)
#      77         for epoch in self.visualize.mb:
#      78             self.current_epoch = epoch
# ---> 79             self.train_one_epoch()
#      80             self.save_checkpoint()
#      81
#
# E:\vinbrain-internship\segmentation\train\train.py in train_one_epoch(self)
#      94
#      95             self.optimizer.zero_grad()
# ---> 96             loss.backward()
#      97             self.optimizer.step()
#      98
#
# ~\anaconda3\envs\segmentation\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\anaconda3\envs\segmentation\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# # Test Model

# %%
from data.SegmentationData import SegmentationData
from config import config
data = SegmentationData(config)

# %%
from model.Unet import Unet
import torch
x = torch.ones([1, 1, 192, 192])
net = Unet(1, 1, padding = 1)
x.shape, net(x).shape

# %%
from model.Unet import Up
import torch
x = torch.empty([1, 1024, 4, 4])
up = Up([1024, 512, 512])
up(x)

# %%
import torch.nn as nn
from model.Unet import MultiConv
MultiConv([2, 1, 1], True, 0)(x1)

nn.BatchNorm2d(1)(x2).sum()

# %%
import torch
import torch.nn.functional as F



diffY = x2.size()[2] - x1.size()[2]
diffX = x2.size()[3] - x1.size()[3]

x2 = F.pad(x2, [
        -diffX//2, -diffX//2,
        -diffY//2, -diffY//2
        ])
x1.shape, x2.shape

# %% [markdown]
# # Test BrainTumorDataset

# %%
from dataset.BrainTumorDataset import BrainTumorDataset
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(256),
    transforms.ToTensor()
]
)
dataset_args = {
    "input_folder":'E:\data\BrainTumor',
}
dataset = BrainTumorDataset(dataset_args, transform_train, "train")

# %%
dataset.show_sample()

# %% [markdown]
# # Test split train val

# %%
from dataset.BrainTumorDataset import PrepairBrainTumorDataset
prepaireDataset = PrepairBrainTumorDataset('E:\data\BrainTumorRaw','E:\data\BrainTumor')
prepaireDataset.split_train_test_val()
